# %% [markdown]
# **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
#to see plots in the notebook

# %%
# %matplotlib inline

# %% [markdown]
# There are 2 methods to plot graph using matplotlib.

# %% [markdown]
# 1. **Normal method**

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'r')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Plot')
plt.show()

# %% [markdown]
# # subplots

# %%
plt.subplot(1, 2, 1) # 1 row, 2 column, 1st plot
plt.plot(x, y, 'g--')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-')

# %% [markdown]
# 2. **Object oriented method**(The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.)

# %%
# Creating an empty canvas
fig = plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height(range 0 to 1)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y, 'g')
axes.set_xlabel('x-axis')
axes.set_ylabel('y-axis')
axes.set_title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.plot(x, y, 'g')
axes.set_title('X vs Y')

axes2 = fig.add_axes([0.2, 0.6, 0.3, 0.2])
axes2.plot(y, x, 'r')
axes2.set_title('Y vs X')
# Out:
# Text(0.5, 1.0, 'Y vs X')

# %% [markdown]
# # subplots

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 2)
axes[0].plot(x, y, 'r')
axes[1].plot(y, x, 'g')
#plt.show()

# %% [markdown]
# **Figure size and DPI**

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(8, 4), dpi = 400)
axes = fig.add_axes([0.1, 0.1, 0.8, 1])
axes.plot(x, y)

# %% [markdown]
# **Saving figures**

# %%
fig

# %%
fig.savefig("X vs Y.png") # we can also save in jpg, jpeg etc... we can also set dpi while saving

# %% [markdown]
# **Legends, labels, title**

# %%
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 1, 0.4])
axes.plot(x, x**2, 'r*-', label = 'X squared')
axes.plot(x, x**3, 'g*-', label = 'X cubed')
axes.set_title('X vs Y')
axes.set_xlabel('X-axis')
axes.set_ylabel('Y-axis')
axes.legend(loc=0) # loc 0 selects the best possible place for legend. **legend search for labels in each plot**
